# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import re
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# !pip list -o
# Out:
# Package                      Version      Latest       Type
# ---------------------------- ------------ ------------ -----
# absl-py                      1.4.0        2.3.1        wheel
# albucore                     0.0.24       0.0.33       wheel
# antlr4-python3-runtime       4.9.3        4.13.2       wheel
# atpublic                     5.1          6.0.1        wheel
# bigframes                    2.14.0       2.15.0       wheel
# blosc2                       3.6.1        3.7.0        wheel
# Bottleneck                   1.4.2        1.5.0        wheel
# cachetools                   5.5.2        6.1.0        wheel
# cmake                        3.31.6       4.1.0        wheel
# cryptography                 43.0.3       45.0.6       wheel
# cuda-python                  12.6.2.post1 13.0.0       wheel
# cudf-cu12                    25.6.0       25.8.0       wheel
# cudf-polars-cu12             25.6.0       25.8.0       wheel
# cuml-cu12                    25.6.0       25.8.0       sdist
# cupy-cuda12x                 13.3.0       13.5.1       wheel
# cuvs-cu12                    25.6.1       25.8.0       sdist
# cvxpy                        1.6.7        1.7.1        wheel
# Cython                       3.0.12       3.1.3        wheel
# dask                         2025.5.0     2025.7.0     wheel
# dask-cuda                    25.6.0       25.8.0       wheel
# dask-cudf-cu12               25.6.0       25.8.0       wheel
# dataproc-spark-connect       0.8.3        0.9.0        wheel
# dbus-python                  1.2.18       1.4.0        sdist
# debugpy                      1.8.15       1.8.16       wheel
# decorator                    4.4.2        5.2.1        wheel
# dill                         0.3.8        0.4.0        wheel
# distributed                  2025.5.0     2025.7.0     wheel
# distributed-ucxx-cu12        0.44.0       0.45.1       wheel
# dlib                         19.24.6      20.0.0       sdist
# docutils                     0.21.2       0.22         wheel
# earthengine-api              1.5.24       1.6.3        wheel
# fastai                       2.7.19       2.8.3        wheel
# fastcore                     1.7.29       1.8.7        wheel
# firebase-admin               6.9.0        7.1.0        wheel
# flax                         0.10.6       0.11.1       wheel
# fsspec                       2025.3.0     2025.7.0     wheel
# gcsfs                        2025.3.0     2025.7.0     wheel
# GDAL                         3.8.4        3.11.3       sdist
# geemap                       0.35.3       0.36.1       wheel
# google                       2.0.3        3.0.0        wheel
# google-ai-generativelanguage 0.6.15       0.6.18       wheel
# google-api-python-client     2.178.0      2.179.0      wheel
# google-auth                  2.38.0       2.40.3       wheel
# google-cloud-aiplatform      1.108.0      1.109.0      wheel
# google-cloud-storage         2.19.0       3.3.0        wheel
# google-genai                 1.29.0       1.30.0       wheel
# grpcio-status                1.71.2       1.74.0       wheel
# gym                          0.25.2       0.26.2       sdist
# ibis-framework               9.5.0        10.8.0       wheel
# intel-cmplr-lib-ur           2025.2.0     2025.2.1     wheel
# intel-openmp                 2025.2.0     2025.2.1     wheel
# ipykernel                    6.17.1       6.30.1       wheel
# ipyparallel                  8.8.0        9.0.1        wheel
# ipython                      7.34.0       9.4.0        wheel
# ipywidgets                   7.7.1        8.1.7        wheel
# jax                          0.5.3        0.7.0        wheel
# jax-cuda12-pjrt              0.5.3        0.7.0        wheel
# jax-cuda12-plugin            0.5.3        0.7.0        wheel
# jaxlib                       0.5.3        0.7.0        wheel
# jupyter-client               6.1.12       8.6.3        wheel
# jupyter-console              6.1.0        6.6.3        wheel
# jupyter_kernel_gateway       2.5.2        3.0.1        wheel
# jupyter-server               1.16.0       2.16.0       wheel
# keras                        3.10.0       3.11.2       wheel
# langsmith                    0.4.13       0.4.14       wheel
# launchpadlib                 1.10.16      2.1.0        wheel
# lazr.restfulclient           0.14.4       0.14.6       wheel
# lazr.uri                     1.0.6        1.0.7        wheel
# libcudf-cu12                 25.6.0       25.8.0       wheel
# libcugraph-cu12              25.6.0       25.8.0       sdist
# libcuml-cu12                 25.6.0       25.8.0       sdist
# libcuvs-cu12                 25.6.1       25.8.0       sdist
# libkvikio-cu12               25.6.0       25.8.0       wheel
# libraft-cu12                 25.6.0       25.8.0       wheel
# librmm-cu12                  25.6.0       25.8.0       wheel
# libucxx-cu12                 0.44.0       0.45.1       wheel
# llvmlite                     0.43.0       0.44.0       wheel
# lxml                         5.4.0        6.0.0        wheel
# Mako                         1.1.3        1.3.10       wheel
# matplotlib                   3.10.0       3.10.5       wheel
# mizani                       0.13.5       0.14.2       wheel
# moviepy                      1.0.3        2.2.1        wheel
# multiprocess                 0.70.16      0.70.18      wheel
# music21                      9.3.0        9.7.1        wheel
# narwhals                     2.1.0        2.1.1        wheel
# notebook                     6.5.7        7.4.5        wheel
# numba                        0.60.0       0.61.2       wheel
# numba-cuda                   0.11.0       0.18.1       wheel
# numpy                        2.0.2        2.3.2        wheel
# nvidia-cublas-cu12           12.5.3.2     12.9.1.4     wheel
# nvidia-cuda-cupti-cu12       12.5.82      12.9.79      wheel
# nvidia-cuda-nvcc-cu12        12.5.82      12.9.86      wheel
# nvidia-cuda-nvrtc-cu12       12.5.82      12.9.86      wheel
# nvidia-cuda-runtime-cu12     12.5.82      12.9.79      wheel
# nvidia-cudnn-cu12            9.3.0.75     9.12.0.46    wheel
# nvidia-cufft-cu12            11.2.3.61    11.4.1.4     wheel
# nvidia-curand-cu12           10.3.6.82    10.3.10.19   wheel
# nvidia-cusolver-cu12         11.6.3.83    11.7.5.82    wheel
# nvidia-cusparse-cu12         12.5.1.3     12.5.10.65   wheel
# nvidia-cusparselt-cu12       0.6.2        0.8.0        wheel
# nvidia-ml-py                 12.575.51    13.580.65    wheel
# nvidia-nccl-cu12             2.23.4       2.27.7       wheel
# nvidia-nvjitlink-cu12        12.5.82      12.9.86      wheel
# nvidia-nvtx-cu12             12.4.127     12.9.79      wheel
# nx-cugraph-cu12              25.6.0       25.8.0       sdist
# openai                       1.99.8       1.99.9       wheel
# orjson                       3.11.1       3.11.2       wheel
# pandas                       2.2.2        2.3.1        wheel
# pandas-stubs                 2.2.2.240909 2.3.0.250703 wheel
# pip                          24.1.2       25.2         wheel
# plotly                       5.24.1       6.3.0        wheel
# plotnine                     0.14.5       0.15.0       wheel
# polars                       1.25.2       1.32.2       wheel
# portpicker                   1.5.2        1.6.0        wheel
# protobuf                     5.29.5       6.31.1       wheel
# psutil                       5.9.5        7.0.0        wheel
# psygnal                      0.14.0       0.14.1       wheel
# py4j                         0.10.9.7     0.10.9.9     wheel
# pyarrow                      18.1.0       21.0.0       wheel
# pydantic_core                2.33.2       2.39.0       wheel
# pydot                        3.0.4        4.0.1        wheel
# PyGObject                    3.42.0       3.52.3       sdist
# pylibcudf-cu12               25.6.0       25.8.0       wheel
# pylibcugraph-cu12            25.6.0       25.8.0       sdist
# pylibraft-cu12               25.6.0       25.8.0       wheel
# pyOpenSSL                    24.2.1       25.1.0       wheel
# pyspark                      3.5.1        4.0.0        sdist
# pytensor                     2.31.7       2.32.0       wheel
# pyzmq                        26.2.1       27.0.1       wheel
# raft-dask-cu12               25.6.0       25.8.0       wheel
# rapids-dask-dependency       25.6.0       25.8.0       wheel
# regex                        2024.11.6    2025.7.34    wheel
# requests                     2.32.3       2.32.4       wheel
# requirements-parser          0.9.0        0.13.0       wheel
# rich                         13.9.4       14.1.0       wheel
# rmm-cu12                     25.6.0       25.8.0       wheel
# rpy2                         3.5.17       3.6.2        wheel
# scikit-learn                 1.6.1        1.7.1        wheel
# sentencepiece                0.2.0        0.2.1        wheel
# setuptools                   75.2.0       80.9.0       wheel
# sqlglot                      25.20.2      27.7.0       wheel
# sympy                        1.13.1       1.14.0       wheel
# tensorboard                  2.19.0       2.20.0       wheel
# tensorflow                   2.19.0       2.20.0       wheel
# thinc                        8.3.6        9.1.1        wheel
# toolz                        0.12.1       1.0.0        wheel
# torch                        2.6.0+cu124  2.8.0        wheel
# torchao                      0.10.0       0.12.0       wheel
# torchaudio                   2.6.0+cu124  2.8.0        wheel
# torchvision                  0.21.0+cu124 0.23.0       wheel
# tornado                      6.4.2        6.5.2        wheel
# traitlets                    5.7.1        5.14.3       wheel
# transformers                 4.55.0       4.55.2       wheel
# triton                       3.2.0        3.4.0        wheel
# ucx-py-cu12                  0.44.0       0.45.0       sdist
# ucxx-cu12                    0.44.0       0.45.1       wheel
# wadllib                      1.3.6        2.0.0        wheel
# widgetsnbextension           3.6.10       4.0.14       wheel
# wrapt                        1.17.2       1.17.3       wheel

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# !pip install -U pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.3.0)

# %%
data=pd.read_csv('/content/Dataset-SA.csv')
data.head()
# Out:
#                                         product_name  product_price  Rate  \
# 0  Candes 12 L Room/Personal Air Cooler??????(Whi...           3999     5
# 1  Candes 12 L Room/Personal Air Cooler??????(Whi...           3999     5
# 2  Candes 12 L Room/Personal Air Cooler??????(Whi...           3999     3
# 3  Candes 12 L Room/Personal Air Cooler??????(Whi...           3999     1
# 4  Candes 12 L Room/Personal Air Cooler??????(Whi...           3999     3
#
#             Review                                            Summary  \
# 0           super!  great cooler excellent air flow and for this p...
# 1          awesome              best budget 2 fit cooler nice cooling
# 2             fair  the quality is good but the power of air is de...
# 3  useless product                  very bad product its a only a fan
# 4             fair                                      ok ok product
#
#   Sentiment
# 0  positive
# 1  positive
# 2  positive
# 3  negative
# 4   neutral

# %%
pd.unique(data['rating'])

# %%
data.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-169168403.py in <cell line: 0>()
# ----> 1 data.info()
#
# NameError: name 'data' is not defined

# %%
sns.countplot(data=data,
              x='rating',
              order=data.rating.value_counts().index)

# %%
# rating label if rating is <= 4, then replace it  negative(0) else positive(1)
pos_neg = []
for i in range(len(data['rating'])):
    if data['rating'][i] >= 5:
        pos_neg.append(1)
    else:
        pos_neg.append(0)

data['label'] = pos_neg
nltk.download('punkt')
from tqdm import tqdm

def preprocess_text(text_data):
    preprocessed_text = []

    for sentence in tqdm(text_data):
        # Removing punctuations
        sentence = re.sub(r'[^\w\s]', '', sentence)

        # Converting lowercase and removing stopwords
        preprocessed_text.append(' '.join(token.lower()
                                        for token in nltk.word_tokenize(sentence)
                                        if token.lower() not in stopwords.words('english')))

    return preprocessed_text

# %%
preprocessed_review = preprocess_text(data['review'].values)
data['review'] = preprocessed_review

# %%
data.head()

# %%
data["label"].value_counts()
